# %%
import matplotlib.pyplot as plt
sizes = [1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,25000,50000,100000]

# %%
def func(file:str, comparisons:list, copies:list)->None:
    for line in open(file).readlines():
        a,b=line.split()
        comparisons.append(int(a))
        copies.append(int(b))

# %%
selection_random_comparisons=[]
selection_random_copies=[]
func("selection_random_stats_file.txt",selection_random_comparisons,selection_random_copies)
print(len(selection_random_comparisons))
print(len(sizes))
plt.figure(figsize=(10,5))
plt.plot(sizes, selection_random_comparisons, color = "red")
plt.plot(sizes, selection_random_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Selection_Random")
# Out:
# 13
# 13
# Text(0.5, 1.0, 'Selection_Random')

# %%
selection_sorted_comparisons=[]
selection_sorted_copies=[]
func("selection_sorted_stats_file.txt",selection_sorted_comparisons,selection_sorted_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, selection_sorted_comparisons, color = "red")
plt.plot(sizes, selection_sorted_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Selection_Sorted")
# Out:
# Text(0.5, 1.0, 'Selection_Sorted')

# %%
selection_reverse_sorted_comparisons=[]
selection_reverse_sorted_copies=[]
func("selection_reverse_sorted_stats_file.txt",selection_reverse_sorted_comparisons,selection_reverse_sorted_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, selection_reverse_sorted_comparisons, color = "red")
plt.plot(sizes, selection_reverse_sorted_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Selection_Reverse_Sorted")
# Out:
# Text(0.5, 1.0, 'Selection_Reverse_Sorted')

# %%
shaker_random_comparisons=[]
shaker_random_copies=[]
func("shaker_random_stats_file.txt",shaker_random_comparisons,shaker_random_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, shaker_random_comparisons, color = "red")
plt.plot(sizes, shaker_random_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Shaker_Random")
# Out:
# Text(0.5, 1.0, 'Shaker_Random')

# %%
shaker_sorted_comparisons=[]
shaker_sorted_copies=[]
func("shaker_sorted_stats_file.txt",shaker_sorted_comparisons,shaker_sorted_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, shaker_sorted_comparisons, color = "red")
plt.plot(sizes, shaker_sorted_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Shaker_Sorted")
# Out:
# Text(0.5, 1.0, 'Shaker_Sorted')

# %%
shaker_reverse_sorted_comparisons=[]
shaker_reverse_sorted_copies=[]
func("shaker_reverse_sorted_stats_file.txt",shaker_reverse_sorted_comparisons,shaker_reverse_sorted_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, shaker_reverse_sorted_comparisons, color = "red")
plt.plot(sizes, shaker_reverse_sorted_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Shaker_Reverse_Sorted")
# Out:
# Text(0.5, 1.0, 'Shaker_Reverse_Sorted')

# %%
comb_random_comparisons=[]
comb_random_copies=[]
func("comb_random_stats_file.txt",comb_random_comparisons,comb_random_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, comb_random_comparisons, color = "red")
plt.plot(sizes, comb_random_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Comb_Random")
# Out:
# Text(0.5, 1.0, 'Comb_Random')

# %%
comb_sorted_comparisons=[]
comb_sorted_copies=[]
func("comb_sorted_stats_file.txt",comb_sorted_comparisons,comb_sorted_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, comb_sorted_comparisons, color = "red")
plt.plot(sizes, comb_sorted_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Comb_Sorted")
# Out:
# Text(0.5, 1.0, 'Comb_Sorted')

# %%
comb_reverse_sorted_comparisons=[]
comb_reverse_sorted_copies=[]
func("comb_reverse_sorted_stats_file.txt",comb_reverse_sorted_comparisons,comb_reverse_sorted_copies)
plt.figure(figsize=(10,5))
plt.plot(sizes, comb_reverse_sorted_comparisons, color = "red")
plt.plot(sizes, comb_reverse_sorted_copies, color = "blue")
plt.legend(["Comparisons", "Copies"])
plt.title("Comb_Reverse_Sorted")
# Out:
# Text(0.5, 1.0, 'Comb_Reverse_Sorted')
